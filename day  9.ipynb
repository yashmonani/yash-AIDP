# %%
import cv2
import skimage
import matplotlib.pyplot as plt
import numpy as np
img1 = plt.imread("car 1.jpg")
import skimage as ski
plt.imshow(img1)

# %%
#Image Type Conversion
#Colour image to gray 
#to binary
#Geometric transformation
#cropping
#scaling
#rotation
#Image Arithmetic /brightness, contrast, adjustmemts
#Addition
# Subtracting
# Multiplication
# Division
# Brightness and constrast adjustmemts
#Blurring and sharpening
# Morphology
# Structing element
# Dilation
# Erosing
# Closing 
# Opening
# Removing small holes
# Removing small objects
# Region properties
# Feature detection
# Extraction
# Macthing

# %%
img_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray)
img_gray.shape
# Out:
# (756, 1680)

# %%
plt.imshow(img_gray, cmap= 'gray')

# %%
th, img_bin = cv2.threshold(img_gray, 70,255,cv2.THRESH_BINARY)#70 se upar wale value white and niche wale black
img_bin.shape
# Out:
# (756, 1680)

# %%
plt.imshow(img_bin, cmap='gray')

# %%
plt.imshow(img1[:200,200:400,::-1])#cmap='gray')

# %%
x,y,w,h =(50,150,80,140)
plt.imshow(img1[y:y+h, x:x+w, ::-1])

# %%
x,y,w,h =(50,150,80,140)
plt.imshow(img1[y:y+h, x:x+w, ::-1])
plt.imshow()
#plt.suplot

x1,y1,x2,y2 =(50,150,270,210)
plt.imshow(img1[y1:y2, x1:x2, ::-1])
plt.imshow()

x,y,w,h =(50,150,80,140)
plt.imshow(img1[y1:y2, x1:x2, ::-1])
plt.imshow()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 x,y,w,h =(50,150,80,140)
#       2 plt.imshow(img1[y:y+h, x:x+w, ::-1])
# ----> 3 plt.imshow()
#       5 x1,y1,x2,y2 =(50,150,270,210)
#       6 plt.imshow(img1[y1:y2, x1:x2, ::-1])
#
# TypeError: imshow() missing 1 required positional argument: 'X'

# %%
img_large = cv2.resize(img1, (1500,1500),interpolation=cv2.INTER_CUBIC )#here interpolation is an approach to algorithm
img_large.shape
# Out:
# (1500, 1500, 3)

# %%
plt.imshow(img_large)

# %% [markdown]
# img_small = cv2.resize(
#     img1, (0,0),fx=0.25, fy=0.25,interpolation=cv2.INTER_CUBIC )

# %%
plt.imshow(img_small)
img_small.shape
# Out:
# (189, 420, 3)

# %%
#rotation
img_90=cv2.rotate(img1, cv2.ROTATE_90_CLOCKWISE)
plt.imshow(img_90[:,:,::-1])

# %%
# rot_mat= cv2.getRotationMatrix2D(
#     center=(0,0), angle=30, scale=1.0)
# img_x=cv2.warpAffine(9mg)
img_x=ski.transform.rotate(img1, -30)
plt.imshow(img_x[:,:,::-1])

# %%
#Arithmetic operations


plt.subplot(1,3,1)
plt.title('Darkened')
plt.imshow(img1[:,:,::-1]-20)

# %%
#contrast

# %%
#blurr
plt.subplot(1,2,1)
plt.imshow(img1[:,:,::-1])
plt.subplot(1,2,2)
img_blur = cv2.medianBlur(img1,5)
plt.imshow(img_blur[:,:,::-1])

#sharp

plt.subplot(1,2,1)
plt.imshow(img1[:,:,::-1])
plt.subplot(1,2,2)
shrp_Kernel=np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])
img_sharp = cv2.filter2D(img1, ddepth=-5, kernel=shrp_Kernel)
plt.imshow(img_sharp[:,:,::-1])
